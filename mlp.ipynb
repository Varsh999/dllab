# %% [markdown]
# <a href="https://colab.research.google.com/github/Varsh999/dllab/blob/main/mlp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# -----------------------------
# Activation Functions
# -----------------------------
def sigmoid(x):
    return 1 / (1 + np.exp(-x))

def sigmoid_derivative(a):
    # a = sigmoid(x), so derivative = a * (1 - a)
    return a * (1 - a)

# -----------------------------
# XOR Dataset
# -----------------------------
X = np.array([
    [0, 0],
    [0, 1],
    [1, 0],
    [1, 1]
], dtype=float)

y = np.array([[0], [1], [1], [0]], dtype=float)

# -----------------------------
# Architecture
# -----------------------------
np.random.seed(1)

input_size = 2
hidden_size = 4   # 🔥 increased neurons (more stable)
output_size = 1

W1 = np.random.randn(input_size, hidden_size)
b1 = np.zeros((1, hidden_size))

W2 = np.random.randn(hidden_size, output_size)
b2 = np.zeros((1, output_size))

# -----------------------------
# Training
# -----------------------------
lr = 0.5
epochs = 20000

for epoch in range(epochs):

    # ---- Forward ----
    z1 = np.dot(X, W1) + b1
    a1 = sigmoid(z1)

    z2 = np.dot(a1, W2) + b2
    y_pred = sigmoid(z2)

    # ---- Loss ----
    loss = np.mean((y - y_pred) ** 2)

    # ---- Backprop ----
    error = y - y_pred
    d_z2 = error * sigmoid_derivative(y_pred)

    d_W2 = np.dot(a1.T, d_z2)
    d_b2 = np.sum(d_z2, axis=0, keepdims=True)

    d_a1 = np.dot(d_z2, W2.T)
    d_z1 = d_a1 * sigmoid_derivative(a1)

    d_W1 = np.dot(X.T, d_z1)
    d_b1 = np.sum(d_z1, axis=0, keepdims=True)

    # ---- Update ----
    W2 += lr * d_W2
    b2 += lr * d_b2

    W1 += lr * d_W1
    b1 += lr * d_b1

    if epoch % 2000 == 0:
        print(f"Epoch {epoch}, Loss: {loss:.6f}")

# -----------------------------
# Final Output
# -----------------------------
print("\nFinal Predictions:")
print(y_pred)

print("\nRounded Predictions:")
print(np.round(y_pred))
# Out:
# Epoch 0, Loss: 0.264921
# Epoch 2000, Loss: 0.002302
# Epoch 4000, Loss: 0.000807
# Epoch 6000, Loss: 0.000471
# Epoch 8000, Loss: 0.000328
# Epoch 10000, Loss: 0.000250
# Epoch 12000, Loss: 0.000201
# Epoch 14000, Loss: 0.000167
# Epoch 16000, Loss: 0.000143
# Epoch 18000, Loss: 0.000125
#
# Final Predictions:
# [[0.00557922]
#  [0.99027592]
#  [0.98924615]
#  [0.01416886]]
#
# Rounded Predictions:
# [[0.]
#  [1.]
#  [1.]
#  [0.]]
